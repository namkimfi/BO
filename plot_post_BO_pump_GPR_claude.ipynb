# %% [markdown]
# (copilot)
# 주신 Jupyter 셀 코드를 단계별로 해석해 드리겠습니다:
#
# ```python
# # Jupyter cell — 쉘 명령
# %cd /Users/namkim/Documents/dev_BO_quantum_pump
# !python dev_BO_plotting_code/main.py data/BO_pump_GPR_20260422_165539 --eta-noise-band 0.15
# ```
#
# ---
#
# ### 📌 코드 설명
#
# 1. **`%cd /Users/namkim/Documents/dev_BO_quantum_pump`**
#    - Jupyter의 **매직 명령어** `%cd`를 사용해 현재 작업 디렉토리를 지정된 경로로 변경합니다.
#    - 즉, 이후 실행되는 모든 명령은 `/Users/namkim/Documents/dev_BO_quantum_pump` 폴더 안에서 실행됩니다.
#
# 2. **`!python dev_BO_plotting_code/main.py data/BO_pump_GPR_20260422_165539 --eta-noise-band 0.15`**
#    - `!`는 Jupyter에서 **셸 명령어 실행**을 의미합니다.
#    - `python dev_BO_plotting_code/main.py` → 해당 디렉토리 안의 `main.py` 스크립트를 실행합니다.
#    - `data/BO_pump_GPR_20260422_165539` → 스크립트에 전달되는 첫 번째 인자, 즉 입력 데이터 파일/폴더 경로입니다.
#    - `--eta-noise-band 0.15` → 스크립트 실행 시 옵션 플래그.
#      - `eta-noise-band`라는 파라미터를 `0.15`로 설정합니다.
#      - 아마도 GPR 분석에서 노이즈 밴드(허용 범위)를 지정하는 역할을 할 가능성이 큽니다.
#
# ---
#
# ### ✅ 요약
# 이 셀은 **작업 디렉토리를 프로젝트 폴더로 이동한 뒤**,
# 해당 폴더 안의 `main.py` 스크립트를 실행하면서 **특정 데이터 파일과 옵션(`--eta-noise-band 0.15`)을 인자로 전달**하는 명령입니다.
#
# 즉, **BO_quantum_pump 프로젝트의 데이터 분석/플로팅 코드(main.py)를 지정된 데이터셋에 대해 실행하고, 노이즈 밴드 파라미터를 0.15로 설정하는 과정**이라고 이해하시면 됩니다.
#
# Nam님, 혹시 제가 이 `main.py`가 어떤 역할을 하는지(예: 플롯 생성, 데이터 후처리)까지 추측해서 설명해 드릴까요?

# %%
# Jupyter cell — 쉘 명령
# %cd /Users/namkim/Documents/dev_BO_quantum_pump
# !python dev_BO_plotting_code/main.py data/BO_pump_GPR_20260422_165539 --eta-noise-band 0.15
# Out:
# /Users/namkim/Documents/dev_BO_quantum_pump
# [post-plot v1.1] run: BO_pump_GPR_20260422_165539
#   out: /Users/namkim/Documents/dev_BO_quantum_pump/data/BO_pump_GPR_20260422_165539_postplot
#   η_noise = -2.4434  (stage2_refined)
#   Schoinas 2D (iterated, η-only): 80/80 slices physical; global η_E^min=-3.101 @ V_ent=+146.7 mV, V_exit=+92.2 mV
#   Schoinas (GPR grid): N=16, RMS=0.033, η_E^min=-2.240 @ V_opt=119.9 mV
#   Schoinas (BO-sampled): N=17, RMS=0.108, η_E^min=-2.044 @ V_opt=118.5 mV
#   Sigmoid plateau (6-param phenomenological): N=36, RMS_n=0.496, η_E^min=-3.401 @ V_opt=116.3 mV
#   Decay-cascade (Seo 2014 Eq.(1)): N=35, RMS_n=0.029, η_E^min=-3.872 @ V_opt=119.8 mV, δ₂=ln(Γ₂/Γ₁)=6.55
#   saved -> /Users/namkim/Documents/dev_BO_quantum_pump/data/BO_pump_GPR_20260422_165539_postplot/fig_E1_eta_extrapolation.pdf
#   saved -> /Users/namkim/Documents/dev_BO_quantum_pump/data/BO_pump_GPR_20260422_165539_postplot/fig_E1_eta_extrapolation.png
# ...
